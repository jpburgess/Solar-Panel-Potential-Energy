# %%
import pandas as pd

# %%
df = pd.read_csv("solar_data_2015.csv")
df.head()
# Out:
#             Unnamed: 0  Year  Month  Day  Hour  Minute  GHI  DHI  DNI  \
# 0  2015-01-01 00:00:00  2015      1    1     0       0    0    0    0
# 1  2015-01-01 00:30:00  2015      1    1     0      30    0    0    0
# 2  2015-01-01 01:00:00  2015      1    1     1       0    0    0    0
# 3  2015-01-01 01:30:00  2015      1    1     1      30    0    0    0
# 4  2015-01-01 02:00:00  2015      1    1     2       0    0    0    0
#
#    Wind Speed  Temperature  Cloud Type  Solar Zenith Angle  Surface Albedo  \
# 0         1.6           -3           0              163.68           0.129
# 1         1.6           -3           0              163.45           0.129
# 2         1.6           -3           0              160.95           0.129
# 3         1.6           -3           0              156.92           0.129
# 4         1.7           -3           0              152.03           0.129
#
#    Wind Direction  Pressure  Precipitable Water  Relative Humidity
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             object
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Minute                  int64
# GHI                     int64
# DHI                     int64
# DNI                     int64
# Wind Speed            float64
# Temperature             int64
# Cloud Type              int64
# Solar Zenith Angle    float64
# Surface Albedo        float64
# Wind Direction        float64
# Pressure                int64
# Precipitable Water    float64
# Relative Humidity     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'DHI',
#        'DNI', 'Wind Speed', 'Temperature', 'Cloud Type', 'Solar Zenith Angle',
#        'Surface Albedo', 'Wind Direction', 'Pressure', 'Precipitable Water',
#        'Relative Humidity'],
#       dtype='object')

# %%
df.columns = ['time_stamp','Year', 'Month', 'Day', 'Hour', 'Minute', 'GHI', 'DHI',
       'DNI', 'Wind Speed', 'Temperature', 'Cloud Type', 'Solar Zenith Angle',
       'Surface Albedo', 'Wind Direction', 'Pressure', 'Precipitable Water',
       'Relative Humidity']

# %%
df.head(2)
# Out:
#             time_stamp  Year  Month  Day  Hour  Minute  GHI  DHI  DNI  \
# 0  2015-01-01 00:00:00  2015      1    1     0       0    0    0    0
# 1  2015-01-01 00:30:00  2015      1    1     0      30    0    0    0
#
#    Wind Speed  Temperature  Cloud Type  Solar Zenith Angle  Surface Albedo  \
# 0         1.6           -3           0              163.68           0.129
# 1         1.6           -3           0              163.45           0.129
#
#    Wind Direction  Pressure  Precipitable Water  Relative Humidity
# 0           254.0      1000               0.378               73.5
# 1           254.0      1000               0.381               73.5

# %%
df.isnull()
# Out:
#        time_stamp   Year  Month    Day   Hour  Minute    GHI    DHI    DNI  \
# 0           False  False  False  False  False   False  False  False  False
# 1           False  False  False  False  False   False  False  False  False
# 2           False  False  False  False  False   False  False  False  False
# 3           False  False  False  False  False   False  False  False  False
# 4           False  False  False  False  False   False  False  False  False
# ...           ...    ...    ...    ...    ...     ...    ...    ...    ...
# 17515       False  False  False  False  False   False  False  False  False
# 17516       False  False  False  False  False   False  False  False  False
# 17517       False  False  False  False  False   False  False  False  False
# 17518       False  False  False  False  False   False  False  False  False
# 17519       False  False  False  False  False   False  False  False  False
#
#        Wind Speed  Temperature  Cloud Type  Solar Zenith Angle  \
# ...

# %%
df.dropna()
# Out:
#                 time_stamp  Year  Month  Day  Hour  Minute  GHI  DHI  DNI  \
# 0      2015-01-01 00:00:00  2015      1    1     0       0    0    0    0
# 1      2015-01-01 00:30:00  2015      1    1     0      30    0    0    0
# 2      2015-01-01 01:00:00  2015      1    1     1       0    0    0    0
# 3      2015-01-01 01:30:00  2015      1    1     1      30    0    0    0
# 4      2015-01-01 02:00:00  2015      1    1     2       0    0    0    0
# ...                    ...   ...    ...  ...   ...     ...  ...  ...  ...
# 17515  2015-12-31 21:30:00  2015     12   31    21      30    0    0    0
# 17516  2015-12-31 22:00:00  2015     12   31    22       0    0    0    0
# 17517  2015-12-31 22:30:00  2015     12   31    22      30    0    0    0
# 17518  2015-12-31 23:00:00  2015     12   31    23       0    0    0    0
# 17519  2015-12-31 23:30:00  2015     12   31    23      30    0    0    0
#
#        Wind Speed  Temperature  Cloud Type  Solar Zenith Angle  \
# ...

# %%
len(df)
# Out:
# 17520
